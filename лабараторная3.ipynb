# %% [markdown]
# <a href="https://colab.research.google.com/github/epheemeeral/labs/blob/main/%D0%BB%D0%B0%D0%B1%D0%B0%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Выполнила: Федышина С. П.
# # Группа: АДЭУ-221
# # E-mail: fedyshina.sofiya@mail.ru

# %% [markdown]
# #**3.2.1. Числа**

# %% [markdown]
# #№ 3.2.1
#
# Составьте программу, которая запрашивает у пользователя 2 целых числа и выполняет операции:
#
# арифметические: +, -, * , / , // , %, **;
#
# сравнение: <, <=, >, >=, !=, ==,
#
# выводя на экран результат каждого действия. В случае получение вещественного результата, округлите его до 2-х знаков после запятой (используя функцию round()).

# %%
a = int(input("a=")) #вводим значение а 
b = int(input("b=")) #вводим значение b
print(a + b) #сложение
print(a - b) #вычитание
print(a * b) #умножение
print(round (a / b, 2)) #деление с округлением до двух знаков после запятой
print(a // b) #деление нацело 
print(a % b) #остаток от деления
print(a ** b) #возведение в степень
print(a<b) #меньше
print(a<=b) #меньше или равно
print(a>b) #больше
print(a>=b) #больше или равно
print(a!=b) #неравенство
print(a==b) #проверка равенства чисел
# --------------
# Пример вывода:
#
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True
# True
# False
# False
# True
# False
# Out:
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True
# True
# False
# False
# True
# False

# %% [markdown]
# #№ 3.2.2
#
# Вычислите значение следующего выражения (аргументы - целые числа и вводятся с клавиатуры): ![лаба.png](data:image/png;base64,...)
#
#
# Округлите результат до 3-х знаков после запятой, используя функцию round().

# %%
x = int(input("x=")) #вводим значение x
y = int(input("y=")) #вводим значение y
z = int(input("z=")) #вводим значение z
res = (( (x ** 5 + 7) / (abs (-6) * y) )** (1 / 3) ) / (7 - z % y) #записываем данное выражение в виде кода
print(round(res, 3)) #выводим ответ с округлением до 3 знаков после запятой
# --------------
# Пример вывода:
#
# x=0
# y=1
# z=2
# 0.15
# Out:
# x=0
# y=1
# z=2
# 0.15

# %% [markdown]
# #№ 3.2.3
#
# Дана электрическая цепь, состоящая из 2-х последовательно соединенных проводников (сопротивление каждого известно). Найти общее сопротивление цепи (округление результата необходимо выполнить до 1-го знака после запятой).

# %%
r1 = float(input("r1=")) #ввод значения сопротивления первого проводника
r2 = float(input("r2=")) #ввод значения сопротивления второго проводника
r = r1 + r2 #общее сопротивление равно сумме сопротивлению первого и второго проводников
print(r) #вывод значения общего сопротивления 
# --------------
# Пример вывода:
#
# r1=12.2
# r2=16.1
# 28.3
# Out:
# r1=12.2
# r2=16.1
# 28.3

# %% [markdown]
# # № 3.2.5
#
# С начала суток прошло m минут (0<m≤24∗60). Определите:
#
# целое количество часов, прошедших с начала суток;
#
# количество минут, прошедших с момента начала последнего часа.

# %%
# Количество минут
m = int(input("количество минут, прошедшее с начала суток: ")) #ввод количество минут
h = m // 60 #количество часов, прошедших с начала суток
m2 = m % 60 #количество минут, прошедших с момента начала последнего часа
print("Количество часов, прошедших с начала суток:", h) #вывод
print("Количество минут, прошедших с момента начала последнего часа:", m2) #вывод
# --------------
# Пример вывода:
#
# Количество минут, прошедшее с начала суток: 123
# Количество часов, прошедших с начала суток: 2
# Количество минут, прошедших с момента начала последнего часа: 3
# Out:
# количество минут, прошедшее с начала суток: 123
# Количество часов, прошедших с начала суток: 2
# Количество минут, прошедших с момента начала последнего часа: 3

# %% [markdown]
# # № 3.2.4
#
# Дано двузначное и трехзначное число. Для каждого выведите на экран сумму и произведение цифр.

# %%
num2 = list(map(int, input("двузначное число: "))) #ввод двухзначного числа
num3 = list(map(int, input("трехзначное число: "))) #ввод трехзначного числа
num2_1 = num2[0] #первая цифра числа num2
num2_2 = num2[1] #вторая цифра числа num2
num2_s = num2_1+num2_2 #сумма цифр числа num2
num2_p = num2_1*num2_2 #произведение цифр числа num2
num3_1 = num3[0] #первая цифра числа num3
num3_2 = num3[1] #вторая цифра числа num3
num3_3 = num3[2] #третья цифра числа num3
num3_s = num3_1+num3_2+num3_3 #сумма цифр числа num3
num3_p = num3_1*num3_2*num3_3 #произведение цифр числа num3
print("сумма и произведение цифр двузначного числа: ",num2_s, num2_p) #вывод 
print("сумма и произведение цифр трехзначного числа", num3_s, num3_p) #вывод
# --------------
# Пример вывода:
#
# Двузначное число: 45
# Трехзначное число: 456
# Сумма и произведение цифр двузначного числа: 9 20
# Сумма и произведение цифр трехзначного числа: 15 120
# Out:
# двузначное число: 45
# трехзначное число: 456
# сумма и произведение цифр двузначного числа:  9 20
# сумма и произведение цифр трехзначного числа 15 120

# %% [markdown]
# # № 3.2.6
# Дано уравнение ax + b = 0 и отрезок [m;n]. Ответьте на вопрос, попадает ли решение уравнения в указанный отрезок.

# %%
a = int(input("a=")) #ввод значения а
b = int(input("b=")) #ввод значения b
m = int(input("m=")) #ввод значения m
n = int(input("n=")) #ввод значения n
x = -b / a #выражаем x из данного уравнения
is_ok = bool((x>=m) and (x<=n)) #проверяем удовлетворяет ли значение x условию задачи
print("попадает:", is_ok) #выводим результат (true или false)
# --------------
# Пример вывода:
#
# Введите a = 1
# Введите b = 2
# Введите m = -5
# Введите n = 5
# Попадает: True
# Out:
# a=1
# b=2
# m=-5
# n=5
# попадает: True

# %% [markdown]
# # **3.2.2. Строки**
# # № 3.2.7
#
# Составьте программу, которая запрашивает название футбольной команды и повторяет его на экране со словами
#
# ... - чемпион!
# После этого выполните:
#
# используя операцию дублирования, нарисуйте черту (набор "-"), длиной, равной размеру названия команды;
#
# преобразуйте строку в нижний регистр и выведите на экран:
#
# длину наименования команды;
#
# есть ли в наименовании команды буква "п" (True/False)?
#
# сколько раз повторяется буква "а"?

# %%
team = input("Введите название команды: ") #ввод
print(team, "- чемпион!") #вывод
print("-"*len(team)) #вывод - длиной, равной размеру названия команды
team_lowercase = print(team.lower()) #преобразование строки в нижний регистр
print("Символов в названии команды:",len(team)) #вывод
print("Буква 'п' есть:",bool("п" in "Спартак")) #вывод
print('Количество букв "а":',team.find('а')) #вывод
# --------------
# Пример вывода:
#
# Введите название команды: Спартак
# Спартак - чемпион!
# -------
# Символов в названии команды: 7
# Буква "п" есть: True
# Количество букв "а":2
# Out:
# Введите название команды: Спартак
# Спартак - чемпион!
# -------
# спартак
# Символов в названии команды: 7
# Буква 'п' есть: True
# Количество букв "а": 2

# %% [markdown]
# # № 3.2.8
#
# Составьте программу, которая запрашивает название государства и его столицы, а затем выводит сообщение:
#
# Государство - ..., столица - ...

# %%
country = input() #ввод
capital = input() #ввод
a="Государство -" #задаем значение а
b="столица -" #задаем значение b
c = "{} {}, {} {}".format(a,country,b,capital) #задаем значение с
print(c) #вывод
# --------------
# Пример вывода:
#
# Введите название государства: Россия
# Введите название столицы: Москва
# Государство - Россия, столица - Москва
# Out:
# Россия
# Москва
# Государство - Россия, столица - Москва

# %% [markdown]
# # № 3.2.9
#
# Дано слово объектно-ориентированный. Используя индексацию и срезы составьте из него слова объект, ориентир, тир, кот, рента и выведите их на экран.

# %%
word = "объектно-ориентированный"
w1 = word[:6]  #слово объект
w2 = word[9:17] #слово ориентир
w3 = word[14:17] #слово тир
w4 = word[4]+word[7]+word[5] #слово кот
w5 = word[10]+word[12:15]+word[19] #слово рента
print(w1, w2, w3, w4, w5, sep="\n") #вывод слов в столбик(разделение)
# --------------
# Пример вывода:
#
# объект
# ориентир
# тир
# кот
# рента
# Out:
# объект
# ориентир
# тир
# кот
# рента

# %% [markdown]
# # **3.2.3. Структуры данных**
# # № 3.2.10
#
# Создайте 2 пустых списка и выполните операции, описанные в заготовке.

# %%
# Создать 2 пустых списка
a = [ ]
b = [ ]
# Добавить 2 вещественных числа (4.5 и 3.4) в список 'a' с помощью append
a.append(4.5)
a.append(3.4)
# Добавить 2 вещественных числа (8.7, 1.3) в список 'a' с помощью extend
m=[8.7, 1.3]
a.extend(m)
# Добавить 2 вещественных числа (14.5, 3.4) в список 'b' с помощью append
b.append(14.5)
b.append(3.4)
# Добавить 2 вещественных числа (8.7, 11.3) в список 'b'с помощью extend
n=[8.7, 11.3]
b.extend(n)
# Вставить целое число 100 на 2-е и 4-е место списка 'a'
a.insert(1, 100)
a.insert(3, 100)
# Вставить целое число 200 на 1-е и 3-е место списка 'b'
b.insert(0, 200)
b.insert(2, 200)
# Вывести списки на экран
print("Исходные списки:")
print("1-й", a)
print("2-й", b)
# Удалить первые элементы из списков 'a' и 'b'
del a[0]
del b[0]
# Удалить элемент 100 из списка 'a'
a.remove(100)
# Удалить элемент 200 из списка 'b'
b.remove(200)
# Вывести списки на экран
print("\nПосле удалений:")
# Удалите комментарий и допишите код
print(a)
print(b)
# Создать множества из списков 'a' и 'b', а также их пересечение
sa = set(a)
sb = set(b)
sa_and_sb = sa & sb
# Вывести экран уникальные элементы каждого списка и общие
print("\nУникальные элементы:")
print(sa)
print(sb)
# Удалите комментарий и допишите код
print("общие:", sa_and_sb)
# Соединить списки 'a' и 'b'
c = a + b
# Отсортировать список 'c' по возрастанию и убыванию
c_asc = sorted(c, key=None, reverse=False)
c_desc = sorted(c, key=None, reverse=True)
# Максимальный и минимальный элементы
c_max = max(c)
c_min = min(c)
# Вывести результаты на экран
print("\nИтоговые:")
print("3-й:", c)
print("cортировка (возр.):", c_asc)
print("cортировка (убыв.):", c_desc)
print("макс. и мин.:", c_max, c_min)
# --------------
# Пример вывода:
#
# Исходные списки:
# 1-й: [4.5, 100, 3.4, 100, 8.7, 1.3]
# 2-й: [200, 14.5, 200, 3.4, 8.7, 11.3]
#
# После удалений:
# 1-й: [3.4, 100, 8.7, 1.3]
# 2-й: [14.5, 3.4, 8.7, 11.3]
#
# Уникальные элементы:
# 1-й: {8.7, 1.3, 3.4, 100}
# 2-й: {8.7, 11.3, 3.4, 14.5}
# общие: {8.7, 3.4}
#
# Итоговые:
# 3-й: [3.4, 100, 8.7, 1.3, 14.5, 3.4, 8.7, 11.3]
# Сортировка (возр.): [1.3, 3.4, 3.4, 8.7, 8.7, 11.3, 14.5, 100]
# Сортировка (убыв.): [100, 14.5, 11.3, 8.7, 8.7, 3.4, 3.4, 1.3]
# Ср. арифм. = 29.00, ср. геометр. = 7.82
# Макс. и мин.: 100 1.3
# Out:
# Исходные списки:
# 1-й [4.5, 100, 3.4, 100, 8.7, 1.3]
# 2-й [200, 14.5, 200, 3.4, 8.7, 11.3]
#
# После удалений:
# [3.4, 100, 8.7, 1.3]
# [14.5, 3.4, 8.7, 11.3]
#
# Уникальные элементы:
# {8.7, 1.3, 3.4, 100}
# {8.7, 11.3, 3.4, 14.5}
# общие: {8.7, 3.4}
#
# Итоговые:
# 3-й: [3.4, 100, 8.7, 1.3, 14.5, 3.4, 8.7, 11.3]
# cортировка (возр.): [1.3, 3.4, 3.4, 8.7, 8.7, 11.3, 14.5, 100]
# cортировка (убыв.): [100, 14.5, 11.3, 8.7, 8.7, 3.4, 3.4, 1.3]
# макс. и мин.: 100 1.3
